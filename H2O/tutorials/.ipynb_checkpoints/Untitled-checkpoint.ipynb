# %%
import pandas as pd


df = pd.read_csv("../docword.nytimes.txt", delimiter = " ")

# %%
df
# Out:
#                   300000
# 0                 102660
# 1               69679427
# 2                1 413 1
# 3                1 534 1
# 4               1 2340 1
# ...                  ...
# 69679424  300000 59155 3
# 69679425  300000 67026 3
# 69679426  300000 69877 4
# 69679427  300000 80938 3
# 69679428  300000 82350 1
#
# [69679429 rows x 1 columns]

# %%
import h2o
from h2o.automl import H2OAutoML
h2o.init()

df = h2o.import_file(path='/kaggle/input/bank-marketing-campaigns-dataset/bank-additional-full.csv')
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         28 mins 02 secs
# H2O_cluster_timezone:       Europe/Istanbul
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.38.0.3
# H2O_cluster_version_age:    13 days
# H2O_cluster_name:           H2O_from_python_goktug_30ldsj
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.392 Gb
# H2O_cluster_total_cores:    32
# H2O_cluster_allowed_cores:  32
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.10.6 final
# --------------------------  -----------------------------
# ---------------------------------------------------------------------------
# ...
